# %%
import pandas as pd
import missingno as msno


df = pd.read_csv("../input/cleaned_data.csv", index_col="index")

train = df[~df["TARGET"].isnull()]
test = df[df["TARGET"].isnull()]

print(train.shape)
print(test.shape)

# test.to_csv("../input/test_cleaned.csv", index=False)
test.reset_index().to_feather("../input/test_cleaned.feather")
# Out:
# (307507, 782)
# (48744, 782)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 14
#      11 print(test.shape)
#      13 # test.to_csv("../input/test_cleaned.csv", index=False)
# ---> 14 test.to_feather("../input/test_cleaned.feather")
#
# File ~/.conda/envs/tf2/lib/python3.9/site-packages/pandas/core/frame.py:2714, in DataFrame.to_feather(self, path, **kwargs)
#    2689 """
#    2690 Write a DataFrame to the binary Feather format.
#    2691
#    (...)
#    2710 supports custom indices e.g. `to_parquet`.
#    2711 """
#    2712 from pandas.io.feather_format import to_feather
# -> 2714 to_feather(self, path, **kwargs)
#
# File ~/.conda/envs/tf2/lib/python3.9/site-packages/pandas/io/feather_format.py:76, in to_feather(df, path, storage_options, **kwargs)
#      70     raise ValueError(
#      71         f"feather does not support serializing {typ} "
# ...

# %%
df.describe()
# Out:
#           SK_ID_CURR        TARGET    CODE_GENDER   FLAG_OWN_CAR
# count  356251.000000  307507.00000  356251.000000  356251.000000  \
# mean   278128.870078       0.08073       0.660001       0.339699
# std    102842.068890       0.27242       0.473709       0.473608
# min    100001.000000       0.00000       0.000000       0.000000
# 25%    189065.500000       0.00000       0.000000       0.000000
# 50%    278129.000000       0.00000       1.000000       0.000000
# 75%    367192.500000       0.00000       1.000000       1.000000
# max    456255.000000       1.00000       1.000000       1.000000
#
#        FLAG_OWN_REALTY   CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT
# count    356251.000000  356251.000000      3.562510e+05  3.562510e+05  \
# mean          0.306764       0.414312      1.701159e+05  5.877695e+05
# std           0.461151       0.720376      2.235080e+05  3.986253e+05
# min           0.000000       0.000000      2.565000e+04  4.500000e+04
# ...

# %%
import pandas as pd
import shap
import mlflow
from mlflow import MlflowClient


run_id = "0cb98077b68b4bba8ea208b79cb1d2e8"
logged_model = f"runs:/{run_id}/model"

client = MlflowClient()
run = client.get_run(run_id)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
import pandas as pd

from sklearn.model_selection import train_test_split


df = pd.read_csv("../input/cleaned_data.csv", index_col="index")

train = df[~df["TARGET"].isnull()]

print(train.shape)

X_train, X_test, y_train, y_test = train_test_split(train.drop("TARGET", axis=1), train["TARGET"], test_size=0.01, random_state=42, stratify=train["TARGET"])

train = pd.concat([X_test, y_test], axis=1)

print(train.shape)
# test.to_csv("../input/test_cleaned.csv", index=False)
train.reset_index().to_feather("../input/valid_cleaned.feather")
# Out:
# (307507, 782)
# (3076, 782)
